# %%
## Download Dataset
# !pip install opendatasets
import opendatasets as od

# %%
od.download('https://www.kaggle.com/datasets/leonardocipriani/ptbx-xl-ds-small)

# %%
import pandas

# %%
database_file = pandas.read_csv('ptbxl_database.csv')
statements_file = pandas.read_csv('scp_statements.csv')

# %%
database_file.columns
# Out:
# Index(['ecg_id', 'patient_id', 'age', 'sex', 'height', 'weight', 'nurse',
#        'site', 'device', 'recording_date', 'report', 'scp_codes', 'heart_axis',
#        'infarction_stadium1', 'infarction_stadium2', 'validated_by',
#        'second_opinion', 'initial_autogenerated_report', 'validated_by_human',
#        'baseline_drift', 'static_noise', 'burst_noise', 'electrodes_problems',
#        'extra_beats', 'pacemaker', 'strat_fold', 'filename_lr', 'filename_hr'],
#       dtype='object')

# %%
database_file.head()
# Out:
#    ecg_id  patient_id   age  sex  height  weight  nurse  site     device  \
# 0       1     15709.0  56.0    1     NaN    63.0    2.0   0.0  CS-12   E
# 1       2     13243.0  19.0    0     NaN    70.0    2.0   0.0  CS-12   E
# 2       3     20372.0  37.0    1     NaN    69.0    2.0   0.0  CS-12   E
# 3       4     17014.0  24.0    0     NaN    82.0    2.0   0.0  CS-12   E
# 4       5     17448.0  19.0    1     NaN    70.0    2.0   0.0  CS-12   E
#
#         recording_date  ... validated_by_human  baseline_drift static_noise  \
# 0  1984-11-09 09:17:34  ...               True             NaN    , I-V1,
# 1  1984-11-14 12:55:37  ...               True             NaN          NaN
# 2  1984-11-15 12:49:10  ...               True             NaN          NaN
# 3  1984-11-15 13:44:57  ...               True    , II,III,AVF          NaN
# 4  1984-11-17 10:43:15  ...               True   , III,AVR,AVF          NaN
#
# ...

# %%
database_file_treat = database_file.drop(columns=['height', 'weight', 'nurse',
       'site', 'device', 'recording_date', 'heart_axis',
       'infarction_stadium1', 'infarction_stadium2', 'validated_by',
       'second_opinion', 'initial_autogenerated_report','validated_by_human',
       'baseline_drift', 'static_noise', 'burst_noise', 
       'electrodes_problems','extra_beats', 'pacemaker', 
       'strat_fold',])

# %%
database_file_treat.head()
# Out:
#    ecg_id  patient_id   age  sex                                  report  \
# 0       1     15709.0  56.0    1  sinusrhythmus periphere niederspannung
# 1       2     13243.0  19.0    0     sinusbradykardie sonst normales ekg
# 2       3     20372.0  37.0    1              sinusrhythmus normales ekg
# 3       4     17014.0  24.0    0              sinusrhythmus normales ekg
# 4       5     17448.0  19.0    1              sinusrhythmus normales ekg
#
#                                   scp_codes                filename_lr  \
# 0  {'NORM': 100.0, 'LVOLT': 0.0, 'SR': 0.0}  records100/00000/00001_lr
# 1              {'NORM': 80.0, 'SBRAD': 0.0}  records100/00000/00002_lr
# 2                {'NORM': 100.0, 'SR': 0.0}  records100/00000/00003_lr
# 3                {'NORM': 100.0, 'SR': 0.0}  records100/00000/00004_lr
# 4                {'NORM': 100.0, 'SR': 0.0}  records100/00000/00005_lr
#
#                  filename_hr
# 0  records500/00000/00001_hr
# 1  records500/00000/00002_hr
# ...

# %%
statements_file_treat = statements_file.drop(columns=['diagnostic','form','rhythm', 'AHA code', 'aECG REFID', 'CDISC Code', 'DICOM Code'])

# %%
statements_file_treat.head()
# Out:
#   Unnamed: 0                     description diagnostic_class  \
# 0        NDT  non-diagnostic T abnormalities             STTC
# 1       NST_         non-specific ST changes             STTC
# 2        DIG                digitalis-effect             STTC
# 3      LNGQT                long QT-interval             STTC
# 4       NORM                      normal ECG             NORM
#
#   diagnostic_subclass                                 Statement Category  \
# 0                STTC                  other ST-T descriptive statements
# 1                NST_  Basic roots for coding ST-T changes and abnorm...
# 2                STTC                  other ST-T descriptive statements
# 3                STTC                  other ST-T descriptive statements
# 4                NORM                                    Normal/abnormal
#
#     SCP-ECG Statement Description
# 0  non-diagnostic T abnormalities
# 1         non-specific ST changes
# 2       suggests digitalis-effect
# ...

# %%
statements_file_treat.columns
# Out:
# Index(['Unnamed: 0', 'description', 'diagnostic_class', 'diagnostic_subclass',
#        'Statement Category', 'SCP-ECG Statement Description', 'AHA code',
#        'aECG REFID', 'CDISC Code', 'DICOM Code'],
#       dtype='object')
